# %% [markdown]
# 1. **What is a parameter?**
#
#    A parameter is an internal variable in a machine learning model that is learned from the training data, such as weights in linear regression.
#
# 2. **What is correlation?**
#
#    Correlation is a statistical measure that describes the strength and direction of a relationship between two variables.
#
# 3. **What does negative correlation mean?**
#
#    Negative correlation means that as one variable increases, the other variable tends to decrease.
#
# 4. **Define Machine Learning. What are the main components in Machine Learning?**
#
#    Machine Learning is a subset of AI that allows systems to learn and improve from experience without being explicitly programmed. Main components are: Data, Model, Algorithm, Loss Function, Optimizer.
#
# 5. **How does loss value help in determining whether the model is good or not?**
#
#    A low loss value indicates that the model’s predictions are close to the actual values, hence better performance.
#
# 6. **What are continuous and categorical variables?**
#
#    Continuous variables are numeric values with an infinite range (e.g., height). Categorical variables represent categories or labels (e.g., gender).
#
# 7. **How do we handle categorical variables in Machine Learning? What are the common techniques?**
#
#   Common techniques include Label Encoding and One-Hot Encoding using libraries like `sklearn.preprocessing`.
#
# 8. **What do you mean by training and testing a dataset?**
#
#    Training data is used to train the model, while testing data is used to evaluate the model’s performance.
#
# 9. **What is sklearn.preprocessing?**
#
#    It is a module in scikit-learn providing functions for data preprocessing like scaling, encoding, and normalization.
#
# 10. **What is a Test set?**
#
#     A test set is a subset of the dataset used to assess the performance of a trained model.
#
# 11.
#  **How do we split data for model fitting (training and testing) in Python?**
#     Using `train_test_split()` from `sklearn.model_selection`:
#
# ```python
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# ```
#
# 12. **How do you approach a Machine Learning problem?**
#
#     Steps: Define problem, gather data, preprocess data, select model, train model, evaluate, and tune hyperparameters.
#
# 13. **Why do we have to perform EDA before fitting a model to the data?**
#
#     Exploratory Data Analysis helps understand the data structure, detect outliers, and choose appropriate preprocessing techniques.
#
# 14. **What is correlation?**
#
#     Correlation is a statistical measure that describes the strength and direction of a relationship between two variables
#
# 15. **What does negative correlation mean?**
#
#     Negative correlation means that as one variable increases, the other variable tends to decrease
#
# 16. **How can you find correlation between variables in Python?**
#
#     Using pandas:
#
# ```python
# df.corr()
# ```
#
# 17. **What is causation? Explain difference between correlation and causation with an example.**
#
#     Causation implies one variable directly affects another. Correlation only shows a relationship. Example: Ice cream sales and drowning deaths are correlated (due to summer) but one doesn’t cause the other.
#
# 18. **What is an Optimizer? What are different types of optimizers? Explain each with an example.**
#
#     Optimizers update model parameters to minimize loss. Types:
#
# * SGD: Stochastic Gradient Descent
# * Adam: Adaptive Moment Estimation
# * RMSprop: Root Mean Square Propagation
#   Example in TensorFlow:
#
# ```python
# optimizer = tf.keras.optimizers.Adam()
# ```
#
# 19. **What is sklearn.linear\_model?**
#
#     It is a module in scikit-learn for linear models like LinearRegression, LogisticRegression.
#
# 20. **What does model.fit() do? What arguments must be given?**
#
#     `model.fit()` trains the model. Requires features (X) and target (y):
#
# ```python
# model.fit(X_train, y_train)
# ```
#
# 21. **What does model.predict() do? What arguments must be given?**
#
#     `model.predict()` makes predictions on new data:
#
# ```python
# predictions = model.predict(X_test)
# ```
#
# 22. **What are continuous and categorical variables?**
#
#     (Repeated) Already answered in Q6.
#
# 23. **What is feature scaling? How does it help in Machine Learning?**
#
#     Feature scaling normalizes data within a range. It helps algorithms like SVM and k-NN perform better by treating all features equally.
#
# 24. **How do we perform scaling in Python?**
#
#     Using `StandardScaler` from `sklearn.preprocessing`:
#
# ```python
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# ```
#
# 25. **Explain data encoding.**
#
#     Data encoding converts categorical data into numeric form. Techniques: Label Encoding, One-Hot Encoding.
